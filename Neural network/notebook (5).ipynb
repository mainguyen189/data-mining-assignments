# %%
import pandas as pd

file_path = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'

cols = ['age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','label']

data = pd.read_csv(file_path, header=None, names = cols)
data.head()
# Out:
#       age  sex     cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 63.0  1.0  1.0  145.0     233.0   1.0  2.0    150.0      0.0    2.3      3.0
# 67.0  1.0  4.0  160.0     286.0   0.0  2.0    108.0      1.0    1.5      2.0
# 67.0  1.0  4.0  120.0     229.0   0.0  2.0    129.0      1.0    2.6      2.0
# 37.0  1.0  3.0  130.0     250.0   0.0  0.0    187.0      0.0    3.5      3.0
# 41.0  0.0  2.0  130.0     204.0   0.0  2.0    172.0      0.0    1.4      1.0
#
#      slope   ca  label
# 63.0   0.0  6.0      0
# 67.0   3.0  3.0      2
# 67.0   2.0  7.0      1
# 37.0   0.0  3.0      0
# 41.0   0.0  3.0      0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 303 entries, 63.0 to 38.0
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    object
#  11  ca        303 non-null    object
#  12  label     303 non-null    int64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 33.1+ KB

# %%
cont_cols = ['age', 'trestbps', 'chol','thalach','oldpeak']

# %%
#count label distribution
from collections import Counter
print('classes and number of values in dataset', Counter(data['label']))
# Out:
# classes and number of values in dataset Counter({0: 164, 1: 55, 2: 36, 3: 35, 4: 13})

# %%
labels = data['label']
features = data.drop(['label'], axis = 1)

# %%
#dummy the objects features
features = pd.get_dummies(features)
features
# Out:
#       age  sex     cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 63.0  1.0  1.0  145.0     233.0   1.0  2.0    150.0      0.0    2.3      3.0
# 67.0  1.0  4.0  160.0     286.0   0.0  2.0    108.0      1.0    1.5      2.0
# 67.0  1.0  4.0  120.0     229.0   0.0  2.0    129.0      1.0    2.6      2.0
# 37.0  1.0  3.0  130.0     250.0   0.0  0.0    187.0      0.0    3.5      3.0
# 41.0  0.0  2.0  130.0     204.0   0.0  2.0    172.0      0.0    1.4      1.0
# ...   ...  ...    ...       ...   ...  ...      ...      ...    ...      ...
# 45.0  1.0  1.0  110.0     264.0   0.0  0.0    132.0      0.0    1.2      2.0
# 68.0  1.0  4.0  144.0     193.0   1.0  0.0    141.0      0.0    3.4      2.0
# 57.0  1.0  4.0  130.0     131.0   0.0  0.0    115.0      1.0    1.2      2.0
# 57.0  0.0  2.0  130.0     236.0   0.0  2.0    174.0      0.0    0.0      2.0
# 38.0  1.0  3.0  138.0     175.0   0.0  0.0    173.0      0.0    0.0      1.0
#
#       slope_0.0  slope_1.0  slope_2.0  slope_3.0  slope_?  ca_3.0  ca_6.0  \
# 63.0          1          0          0          0        0       0       1
# 67.0          0          0          0          1        0       1       0
# 67.0          0          0          1          0        0       0       0
# 37.0          1          0          0          0        0       1       0
# 41.0          1          0          0          0        0       1       0
# ...         ...        ...        ...        ...      ...     ...     ...
# 45.0          1          0          0          0        0       0       0
# 68.0          0          0          1          0        0       0       0
# 57.0          0          1          0          0        0       0       0
# 57.0          0          1          0          0        0       1       0
# 38.0          0          0          0          0        1       1       0
#
#       ca_7.0  ca_?
# 63.0       0     0
# 67.0       0     0
# 67.0       1     0
# 37.0       0     0
# 41.0       0     0
# ...      ...   ...
# 45.0       1     0
# 68.0       1     0
# 57.0       1     0
# 57.0       0     0
# 38.0       0     0
#
# [303 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split
features_train, features_test, labels_train, labels_test = train_test_split(features, labels, test_size = 0.2, random_state=23)

# %%
#scale the numeric features
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer

ct = ColumnTransformer([('numeric', StandardScaler(), cont_cols)])

#transform the features
features_train=ct.fit_transform(features_train)
features_test=ct.transform(features_test)

# %%
#now the label
from sklearn.preprocessing import LabelEncoder
import tensorflow
from tensorflow.keras.utils import to_categorical

le = LabelEncoder()
#convert integer encoded labels into binary vector
labels_train = le.fit_transform(labels_train.astype(str))
labels_test = le.transform(labels_test.astype(str))

labels_train = to_categorical(labels_train, dtype='int64')
labels_test = to_categorical(labels_test, dtype='int64')

# %%
features_train.shape
# Out:
# (242, 5)

# %%
labels_train.shape
# Out:
# (242, 5)

# %%
#initiate the model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense
model = Sequential()

model.add(InputLayer(input_shape=(features_train.shape[1],)))

model.add(Dense(12, activation='relu'))
#number of neurons corresponding to number of classes in labels
model.add(Dense(5, activation='softmax'))

# %%
#compile
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics='accuracy')

# %%
#train and evaluate
model.fit(features_train, labels_train, epochs=100, batch_size=16, verbose=1)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 0s 988us/step - loss: 1.7328 - accuracy: 0.1281
# Epoch 2/100
# 16/16 [==============================] - 0s 928us/step - loss: 1.6575 - accuracy: 0.1694
# Epoch 3/100
# 16/16 [==============================] - 0s 949us/step - loss: 1.5931 - accuracy: 0.2273
# Epoch 4/100
# 16/16 [==============================] - 0s 959us/step - loss: 1.5361 - accuracy: 0.3058
# Epoch 5/100
# 16/16 [==============================] - 0s 978us/step - loss: 1.4867 - accuracy: 0.3636
# Epoch 6/100
# 16/16 [==============================] - 0s 960us/step - loss: 1.4434 - accuracy: 0.4421
# Epoch 7/100
# 16/16 [==============================] - 0s 939us/step - loss: 1.4020 - accuracy: 0.4669
# Epoch 8/100
# 16/16 [==============================] - 0s 928us/step - loss: 1.3669 - accuracy: 0.4876
# Epoch 9/100
# 16/16 [==============================] - 0s 952us/step - loss: 1.3361 - accuracy: 0.5041
# Epoch 10/100
# 16/16 [==============================] - 0s 925us/step - loss: 1.3085 - accuracy: 0.5165
# Epoch 11/100
# 16/16 [==============================] - 0s 972us/step - loss: 1.2851 - accuracy: 0.5248
# Epoch 12/100
# 16/16 [==============================] - 0s 934us/step - loss: 1.2638 - accuracy: 0.5331
# Epoch 13/100
# 16/16 [==============================] - 0s 892us/step - loss: 1.2445 - accuracy: 0.5579
# Epoch 14/100
# 16/16 [==============================] - 0s 906us/step - loss: 1.2296 - accuracy: 0.5620
# Epoch 15/100
# 16/16 [==============================] - 0s 872us/step - loss: 1.2159 - accuracy: 0.5579
# Epoch 16/100
# 16/16 [==============================] - 0s 903us/step - loss: 1.2018 - accuracy: 0.5620
# Epoch 17/100
# 16/16 [==============================] - 0s 925us/step - loss: 1.1898 - accuracy: 0.5579
# Epoch 18/100
# Epoch 78/100
# 16/16 [==============================] - 0s 947us/step - loss: 1.0273 - accuracy: 0.5950
# Epoch 79/100
# 16/16 [==============================] - 0s 901us/step - loss: 1.0263 - accuracy: 0.5909
# Epoch 80/100
# 16/16 [==============================] - 0s 932us/step - loss: 1.0261 - accuracy: 0.5868
# Epoch 81/100
# 16/16 [==============================] - 0s 958us/step - loss: 1.0255 - accuracy: 0.5868
# Epoch 82/100
# 16/16 [==============================] - 0s 964us/step - loss: 1.0245 - accuracy: 0.5909
# Epoch 83/100
# 16/16 [==============================] - 0s 909us/step - loss: 1.0249 - accuracy: 0.5909
# Epoch 84/100
# 16/16 [==============================] - 0s 1ms/step - loss: 1.0241 - accuracy: 0.5950
# Epoch 85/100
# 16/16 [==============================] - 0s 935us/step - loss: 1.0235 - accuracy: 0.5950
# Epoch 86/100
# 16/16 [==============================] - 0s 903us/step - loss: 1.0226 - accuracy: 0.5992
# Epoch 87/100
# 16/16 [==============================] - 0s 998us/step - loss: 1.0219 - accuracy: 0.5992
# Epoch 88/100
# 16/16 [==============================] - 0s 906us/step - loss: 1.0213 - accuracy: 0.5992
# Epoch 89/100
# 16/16 [==============================] - 0s 899us/step - loss: 1.0211 - accuracy: 0.5992
# Epoch 90/100
# 16/16 [==============================] - 0s 884us/step - loss: 1.0200 - accuracy: 0.5950
# Epoch 91/100
# 16/16 [==============================] - 0s 930us/step - loss: 1.0195 - accuracy: 0.5950
# Epoch 92/100
# 16/16 [==============================] - 0s 861us/step - loss: 1.0189 - accuracy: 0.5992
# Epoch 93/100
# 16/16 [==============================] - 0s 851us/step - loss: 1.0178 - accuracy: 0.5992
# Epoch 94/100
# 16/16 [==============================] - 0s 858us/step - loss: 1.0174 - accuracy: 0.5992
# Epoch 95/100
# 16/16 [==============================] - 0s 867us/step - loss: 1.0167 - accuracy: 0.5950
# Epoch 96/100
# 16/16 [==============================] - 0s 896us/step - loss: 1.0167 - accuracy: 0.5992
# Epoch 97/100
# 16/16 [==============================] - 0s 911us/step - loss: 1.0162 - accuracy: 0.5950
# Epoch 98/100
# 16/16 [==============================] - 0s 900us/step - loss: 1.0156 - accuracy: 0.6033
# Epoch 99/100
# 16/16 [==============================] - 0s 891us/step - loss: 1.0151 - accuracy: 0.5950
# Epoch 100/100
# 16/16 [==============================] - 0s 901us/step - loss: 1.0146 - accuracy: 0.5992

# %%
#evaluate model

loss, acc = model.evaluate(features_test,labels_test, verbose=1)
print('Loss: ',loss, "| Accuracy: ", acc)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 1.1255 - accuracy: 0.5738
# Loss:  1.1254990100860596 | Accuracy:  0.5737704634666443

# %%
#generate classification report
from sklearn.metrics import classification_report
import numpy as np
labels_estimate=model.predict(features_test, verbose=1)

labels_estimate=np.argmax(labels_estimate, axis=1)
labels_true = np.argmax(labels_test, axis=1)
print(classification_report(labels_estimate,labels_true))
# Out:
# 2/2 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.62      0.75        52
#            1       0.07      0.33      0.12         3
#            2       0.50      0.33      0.40         6
#            3       0.00      0.00      0.00         0
#            4       0.00      0.00      0.00         0
#
#     accuracy                           0.57        61
#    macro avg       0.31      0.26      0.25        61
# weighted avg       0.88      0.57      0.69        61
